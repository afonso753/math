# %%
def smallestMultiple(k):
    n = 2520
    j = 1
    found = True
    while(j <= k):
        if (n%j == 0):
            j+=1
        else:
            n+=1
            j=1
    return n

# %%
smallestMultiple(20)
# Out:
# 232792560
